# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_agora = pd.read_excel('Results/AGORA2_details.xlsx', index_col=0)
df_agora.head()
# Out:
#                                                                                PubSeedID  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176             Abiotrophia defectiva ATCC 49176 (592010.4)
# Acaricomes_phytoseiuli_DSM_14247            Acaricomes phytoseiuli DSM 14247 (1120917.3)
# Acaryochloris_marina_MBIC11017                                                       NaN
# Acetanaerobacterium_elongatum_CGMCC_1_5012                                           NaN
# Acetatifactor_muris_GP69                                                             NaN
#
#                                             2 - complete comparative genomics; 1 - certain comparative genomics; 0 - no comparative genomics  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                                                            2
# Acaricomes_phytoseiuli_DSM_14247                                                            1
# Acaryochloris_marina_MBIC11017                                                              0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                                                  0
# Acetatifactor_muris_GP69                                                                    0
#
#                                                                       Strain  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176            Abiotrophia defectiva ATCC 49176
# Acaricomes_phytoseiuli_DSM_14247            Acaricomes phytoseiuli DSM 14247
# Acaryochloris_marina_MBIC11017                Acaryochloris marina MBIC11017
# Acetanaerobacterium_elongatum_CGMCC_1_5012     Acetanaerobacterium elongatum
# Acetatifactor_muris_GP69                                 Acetatifactor muris
#
#                                                                   Species  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                    Abiotrophia defectiva
# Acaricomes_phytoseiuli_DSM_14247                   Acaricomes phytoseiuli
# Acaryochloris_marina_MBIC11017                       Acaryochloris marina
# Acetanaerobacterium_elongatum_CGMCC_1_5012  Acetanaerobacterium elongatum
# Acetatifactor_muris_GP69                              Acetatifactor muris
#
#                                                           Genus  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                    Abiotrophia
# Acaricomes_phytoseiuli_DSM_14247                     Acaricomes
# Acaryochloris_marina_MBIC11017                    Acaryochloris
# Acetanaerobacterium_elongatum_CGMCC_1_5012  Acetanaerobacterium
# Acetatifactor_muris_GP69                          Acetatifactor
#
#                                                         Family  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                 Aerococcaceae
# Acaricomes_phytoseiuli_DSM_14247                Micrococcaceae
# Acaryochloris_marina_MBIC11017              Acaryochloridaceae
# Acetanaerobacterium_elongatum_CGMCC_1_5012    Oscillospiraceae
# Acetatifactor_muris_GP69                       Lachnospiraceae
#
#                                                       Order  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176            Lactobacillales
# Acaricomes_phytoseiuli_DSM_14247              Micrococcales
# Acaryochloris_marina_MBIC11017              Synechococcales
# Acetanaerobacterium_elongatum_CGMCC_1_5012    Eubacteriales
# Acetatifactor_muris_GP69                      Eubacteriales
#
#                                                                  Class  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                               Bacilli
# Acaricomes_phytoseiuli_DSM_14247                         Actinomycetia
# Acaryochloris_marina_MBIC11017              unclassified Cyanobacteria
# Acetanaerobacterium_elongatum_CGMCC_1_5012                  Clostridia
# Acetatifactor_muris_GP69                                    Clostridia
#
#                                                     Phylum   Kingdom  ...  \
# MicrobeID                                                             ...
# Abiotrophia_defectiva_ATCC_49176                Firmicutes  Bacteria  ...
# Acaricomes_phytoseiuli_DSM_14247            Actinobacteria  Bacteria  ...
# Acaryochloris_marina_MBIC11017               Cyanobacteria  Bacteria  ...
# Acetanaerobacterium_elongatum_CGMCC_1_5012      Firmicutes  Bacteria  ...
# Acetatifactor_muris_GP69                        Firmicutes  Bacteria  ...
#
#                                              Motility  Sample Body Site  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176            Nonmotile               NaN
# Acaricomes_phytoseiuli_DSM_14247            Nonmotile               0.0
# Acaryochloris_marina_MBIC11017              Nonmotile               0.0
# Acetanaerobacterium_elongatum_CGMCC_1_5012     Motile               0.0
# Acetatifactor_muris_GP69                    Nonmotile               0.0
#
#                                             Sample Body Subsite  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                            0.0
# Acaricomes_phytoseiuli_DSM_14247                            0.0
# Acaryochloris_marina_MBIC11017                              0.0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                  0.0
# Acetatifactor_muris_GP69                                    0.0
#
#                                            Genome Size   * assembled  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                           2041839.0
# Acaricomes_phytoseiuli_DSM_14247                           2419519.0
# Acaryochloris_marina_MBIC11017                             8361599.0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                 2916215.0
# Acetatifactor_muris_GP69                                   6013646.0
#
#                                            Gene Count   * assembled  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                             2009.0
# Acaricomes_phytoseiuli_DSM_14247                             2387.0
# Acaryochloris_marina_MBIC11017                               8488.0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                   2842.0
# Acetatifactor_muris_GP69                                     6002.0
#
#                                             GC Count   * assembled  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                          959280.0
# Acaricomes_phytoseiuli_DSM_14247                         1506904.0
# Acaryochloris_marina_MBIC11017                           3926263.0
# Acetanaerobacterium_elongatum_CGMCC_1_5012               1429234.0
# Acetatifactor_muris_GP69                                 2868509.0
#
#                                            GC   * assembled  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                       47.0
# Acaricomes_phytoseiuli_DSM_14247                       62.0
# Acaryochloris_marina_MBIC11017                         47.0
# Acetanaerobacterium_elongatum_CGMCC_1_5012             49.0
# Acetatifactor_muris_GP69                               48.0
#
#                                            CDS Count   * assembled  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                            1950.0
# Acaricomes_phytoseiuli_DSM_14247                            2326.0
# Acaryochloris_marina_MBIC11017                              8409.0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                  2773.0
# Acetatifactor_muris_GP69                                    5901.0
#
#                                             CDS %   * assembled  \
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176                          97.06
# Acaricomes_phytoseiuli_DSM_14247                          97.44
# Acaryochloris_marina_MBIC11017                            99.07
# Acetanaerobacterium_elongatum_CGMCC_1_5012                97.57
# Acetatifactor_muris_GP69                                  98.32
#
#                                                                                   Genome link
# MicrobeID
# Abiotrophia_defectiva_ATCC_49176            ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# Acaricomes_phytoseiuli_DSM_14247            ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# Acaryochloris_marina_MBIC11017              ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000...
# Acetanaerobacterium_elongatum_CGMCC_1_5012  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900...
# Acetatifactor_muris_GP69                    ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900...
#
# [5 rows x 41 columns]

# %%
# taking only the top 20 abundant families
top_families = df_agora.Family.value_counts().nlargest(20).index
df_agora_top_family = df_agora[df_agora.Family.isin(top_families)]
print(top_families)
# Out:
# Index(['Enterobacteriaceae', 'Streptococcaceae', 'Staphylococcaceae',
#        'Enterococcaceae', 'Lachnospiraceae', 'Lactobacillaceae', 'Bacillaceae',
#        'Helicobacteraceae', 'Moraxellaceae', 'Bacteroidaceae',
#        'Clostridiaceae', 'Campylobacteraceae', 'Bifidobacteriaceae',
#        'Pseudomonadaceae', 'Propionibacteriaceae', 'Peptostreptococcaceae',
#        'Oscillospiraceae', 'Prevotellaceae', 'Pasteurellaceae',
#        'Erysipelotrichaceae'],
#       dtype='object', name='Family')

# %%
# taking only the top 20 abundant classes
top_classes = df_agora.Class.value_counts().nlargest(20).index
df_agora_top_class = df_agora[df_agora.Class.isin(top_classes)]
print(top_classes)
# Out:
# Index(['Bacilli', 'Gammaproteobacteria', 'Clostridia', 'Actinomycetia',
#        'Bacteroidia', 'Epsilonproteobacteria', 'Betaproteobacteria',
#        'Coriobacteriia', 'Erysipelotrichia', 'Negativicutes',
#        'Alphaproteobacteria', 'Fusobacteriia', 'Tissierellia', 'Mollicutes',
#        'Spirochaetia', 'Flavobacteriia', 'Deltaproteobacteria', 'Synergistia',
#        'Deinococci', 'Cytophagia'],
#       dtype='object', name='Class')

# %%
# code to plot tsne and umap plots
def plot_tsne_umap(data_all,data_new,df_agora_top_family,df_agora_top_class):
    fig,ax=plt.subplots(2,3,figsize=(25,7),gridspec_kw={'width_ratios': [1, 1, 0.25]})
    def plot(data,ax,l,t1,t2):
        # including only the top 20 families
        data1 = data.loc[df_agora_top_family.index]
        X1 = data1.values
        # getting the family names of the samples in data1 in same order as in data1
        y1 = df_agora_top_family.loc[data1.index,'Family'].values
        # including only the top 20 classes
        data2 = data.loc[df_agora_top_class.index]
        X2 = data2.values
        # getting the class names of the samples in data2 in same order as in data2
        y2 = df_agora_top_class.loc[data2.index,'Class'].values

        tsne1 = TSNE(
            n_components=2,             
            perplexity=30        
        )
        X_tsne1 = tsne1.fit_transform(X1)

        tsne2 = TSNE(
            n_components=2,             
            perplexity=30        
        )
        X_tsne2 = tsne2.fit_transform(X2)
        
        palette1 = sns.color_palette("hsv", len(np.unique(y1)))
        palette2 = sns.color_palette("hsv", len(np.unique(y2)))
        if l:
            sns.scatterplot(x=X_tsne1[:,0], y=X_tsne1[:,1], hue=y1, palette=palette1, legend='full', alpha=0.7,ax=ax[0])
            sns.scatterplot(x=X_tsne2[:,0], y=X_tsne2[:,1], hue=y2, palette=palette2, legend='full', alpha=0.7,ax=ax[1])
            ax[0].legend(ncol=2,bbox_to_anchor=(1.05, 1.1), loc='upper left', borderaxespad=0,fontsize=12)
            ax[1].legend(ncol=2,bbox_to_anchor=(1.05, 1.1), loc='upper left', borderaxespad=0,fontsize=12)
        else:
            sns.scatterplot(x=X_tsne1[:,0], y=X_tsne1[:,1], hue=y1, palette=palette1, legend=False, alpha=0.7,ax=ax[0])
            sns.scatterplot(x=X_tsne2[:,0], y=X_tsne2[:,1], hue=y2, palette=palette2, legend=False, alpha=0.7,ax=ax[1])
        
        # settting the xticks and xticklabels from -100 to 100 with a step of 25
        ax[0].set_xticks(np.arange(-100, 101, 25))
        ax[0].set_yticks(np.arange(-100, 101, 25))
        ax[1].set_xticks(np.arange(-100, 101, 25))
        ax[1].set_yticks(np.arange(-100, 101, 25))
        # setting the x and y axis limits
        ax[0].set_xlim(-100, 100)
        ax[0].set_ylim(-100, 100)
        ax[1].set_xlim(-100, 100)
        ax[1].set_ylim(-100, 100)
        ax[1].set_xticklabels(np.arange(-100, 101, 25), fontsize=12)
        ax[0].set_xticklabels([])
        if l==0:
            ax[0].set_yticklabels(np.arange(-100, 101, 25), fontsize=12)
            ax[1].set_yticklabels(np.arange(-100, 101, 25), fontsize=12)
        else:
            # setting empty xticklabels
            ax[0].set_yticklabels([])
            ax[1].set_yticklabels([])
        
        ax[0].set_title(t1, fontsize=15)
        ax[1].set_title(t2, fontsize=15)
    # code for diff data
    t1 = 'tSNE plot with top 20 abundant families (All reactions)'
    t2 = 'tSNE plot with top 20 abundant classes (All reactions)'
    plot(data_all,[ax[0,0],ax[1,0]],0,t1,t2)
    t1 = 'tSNE plot with top 20 abundant families (New reactions)'
    t2 = 'tSNE plot with top 20 abundant classes (New reactions)'
    plot(data_new,[ax[0,1],ax[1,1]],1,t1,t2)
    # empyting the other one spine
    ax[0,2].axis('off')
    ax[1,2].axis('off')
    plt.savefig('tsne_agora_ss.png', bbox_inches='tight')
    plt.show()
    return fig, ax

# %%
data1= pd.read_csv('Results/tsne_mat_all_ss.csv',index_col=0)
# remiving the .mat string from the ROW column
data1.index = data1.index.str.replace('.mat','',regex=False)
data1.head()
# Out:
#                                             Alanine and aspartate metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                          12
# Acaricomes_phytoseiuli_DSM_14247                                          12
# Acaryochloris_marina_MBIC11017                                            13
# Acetanaerobacterium_elongatum_CGMCC_1_5012                                11
# Acetatifactor_muris_GP69                                                  10
#
#                                             Aminobenzoate degradation  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                    0
# Acaricomes_phytoseiuli_DSM_14247                                    1
# Acaryochloris_marina_MBIC11017                                      1
# Acetanaerobacterium_elongatum_CGMCC_1_5012                          0
# Acetatifactor_muris_GP69                                            2
#
#                                             Aminophosphonate metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                      0
# Acaricomes_phytoseiuli_DSM_14247                                      0
# Acaryochloris_marina_MBIC11017                                        0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                            0
# Acetatifactor_muris_GP69                                              0
#
#                                             Aminosugar metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                               15
# Acaricomes_phytoseiuli_DSM_14247                               10
# Acaryochloris_marina_MBIC11017                                 13
# Acetanaerobacterium_elongatum_CGMCC_1_5012                      6
# Acetatifactor_muris_GP69                                       14
#
#                                             Arginine and proline metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                         18
# Acaricomes_phytoseiuli_DSM_14247                                         26
# Acaryochloris_marina_MBIC11017                                           32
# Acetanaerobacterium_elongatum_CGMCC_1_5012                               25
# Acetatifactor_muris_GP69                                                 17
#
#                                             Ascorbate and aldarate metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                            0
# Acaricomes_phytoseiuli_DSM_14247                                            0
# Acaryochloris_marina_MBIC11017                                              1
# Acetanaerobacterium_elongatum_CGMCC_1_5012                                  1
# Acetatifactor_muris_GP69                                                    0
#
#                                             Atrazine degradation  \
# Row
# Abiotrophia_defectiva_ATCC_49176                               0
# Acaricomes_phytoseiuli_DSM_14247                               0
# Acaryochloris_marina_MBIC11017                                 0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                     0
# Acetatifactor_muris_GP69                                       0
#
#                                             Benzoate degradation  \
# Row
# Abiotrophia_defectiva_ATCC_49176                               2
# Acaricomes_phytoseiuli_DSM_14247                               1
# Acaryochloris_marina_MBIC11017                                 2
# Acetanaerobacterium_elongatum_CGMCC_1_5012                     2
# Acetatifactor_muris_GP69                                       0
#
#                                             Beta-alanine metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                  2
# Acaricomes_phytoseiuli_DSM_14247                                  7
# Acaryochloris_marina_MBIC11017                                    5
# Acetanaerobacterium_elongatum_CGMCC_1_5012                        5
# Acetatifactor_muris_GP69                                          2
#
#                                             Bile acid metabolism  ...  \
# Row                                                               ...
# Abiotrophia_defectiva_ATCC_49176                               0  ...
# Acaricomes_phytoseiuli_DSM_14247                               0  ...
# Acaryochloris_marina_MBIC11017                                 0  ...
# Acetanaerobacterium_elongatum_CGMCC_1_5012                     0  ...
# Acetatifactor_muris_GP69                                       0  ...
#
#                                             Valerate metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                              0
# Acaricomes_phytoseiuli_DSM_14247                              0
# Acaryochloris_marina_MBIC11017                                0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                    0
# Acetatifactor_muris_GP69                                      0
#
#                                             Valine, leucine, and isoleucine metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                                    34
# Acaricomes_phytoseiuli_DSM_14247                                                    43
# Acaryochloris_marina_MBIC11017                                                      36
# Acetanaerobacterium_elongatum_CGMCC_1_5012                                          25
# Acetatifactor_muris_GP69                                                            32
#
#                                             Vitamin B12 metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                 9
# Acaricomes_phytoseiuli_DSM_14247                                11
# Acaryochloris_marina_MBIC11017                                  40
# Acetanaerobacterium_elongatum_CGMCC_1_5012                      10
# Acetatifactor_muris_GP69                                         8
#
#                                             Vitamin B2 metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                6
# Acaricomes_phytoseiuli_DSM_14247                               12
# Acaryochloris_marina_MBIC11017                                 12
# Acetanaerobacterium_elongatum_CGMCC_1_5012                      4
# Acetatifactor_muris_GP69                                        5
#
#                                             Vitamin B6 metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                               11
# Acaricomes_phytoseiuli_DSM_14247                                7
# Acaryochloris_marina_MBIC11017                                 13
# Acetanaerobacterium_elongatum_CGMCC_1_5012                     14
# Acetatifactor_muris_GP69                                       16
#
#                                             Vitamin C metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                               0
# Acaricomes_phytoseiuli_DSM_14247                               0
# Acaryochloris_marina_MBIC11017                                 0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                     0
# Acetatifactor_muris_GP69                                       0
#
#                                             Wood-Ljungdahl Pathway  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                 0
# Acaricomes_phytoseiuli_DSM_14247                                 1
# Acaryochloris_marina_MBIC11017                                   2
# Acetanaerobacterium_elongatum_CGMCC_1_5012                       1
# Acetatifactor_muris_GP69                                         1
#
#                                             Xenobiotics metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                 0
# Acaricomes_phytoseiuli_DSM_14247                                 2
# Acaryochloris_marina_MBIC11017                                   2
# Acetanaerobacterium_elongatum_CGMCC_1_5012                       1
# Acetatifactor_muris_GP69                                         0
#
#                                             Zeatin biosynthesis  tRNA Charging
# Row
# Abiotrophia_defectiva_ATCC_49176                              1              2
# Acaricomes_phytoseiuli_DSM_14247                              0              2
# Acaryochloris_marina_MBIC11017                                1              2
# Acetanaerobacterium_elongatum_CGMCC_1_5012                    0              2
# Acetatifactor_muris_GP69                                      0              2
#
# [5 rows x 116 columns]

# %%
data2= pd.read_csv('Results/tsne_mat_new_ss.csv',index_col=0)
# removing the .mat string from the ROW column
data2.index = data2.index.str.replace('.mat','',regex=False)
data2.head()
# Out:
#                                             Alanine and aspartate metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                           4
# Acaricomes_phytoseiuli_DSM_14247                                           4
# Acaryochloris_marina_MBIC11017                                             3
# Acetanaerobacterium_elongatum_CGMCC_1_5012                                 4
# Acetatifactor_muris_GP69                                                   3
#
#                                             Aminobenzoate degradation  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                    0
# Acaricomes_phytoseiuli_DSM_14247                                    0
# Acaryochloris_marina_MBIC11017                                      0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                          0
# Acetatifactor_muris_GP69                                            2
#
#                                             Aminophosphonate metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                      0
# Acaricomes_phytoseiuli_DSM_14247                                      0
# Acaryochloris_marina_MBIC11017                                        0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                            0
# Acetatifactor_muris_GP69                                              0
#
#                                             Aminosugar metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                3
# Acaricomes_phytoseiuli_DSM_14247                                1
# Acaryochloris_marina_MBIC11017                                  2
# Acetanaerobacterium_elongatum_CGMCC_1_5012                      0
# Acetatifactor_muris_GP69                                        2
#
#                                             Arginine and proline metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                          7
# Acaricomes_phytoseiuli_DSM_14247                                         12
# Acaryochloris_marina_MBIC11017                                           12
# Acetanaerobacterium_elongatum_CGMCC_1_5012                               10
# Acetatifactor_muris_GP69                                                  3
#
#                                             Ascorbate and aldarate metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                            0
# Acaricomes_phytoseiuli_DSM_14247                                            0
# Acaryochloris_marina_MBIC11017                                              1
# Acetanaerobacterium_elongatum_CGMCC_1_5012                                  1
# Acetatifactor_muris_GP69                                                    0
#
#                                             Atrazine degradation  \
# Row
# Abiotrophia_defectiva_ATCC_49176                               0
# Acaricomes_phytoseiuli_DSM_14247                               0
# Acaryochloris_marina_MBIC11017                                 0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                     0
# Acetatifactor_muris_GP69                                       0
#
#                                             Benzoate degradation  \
# Row
# Abiotrophia_defectiva_ATCC_49176                               2
# Acaricomes_phytoseiuli_DSM_14247                               1
# Acaryochloris_marina_MBIC11017                                 2
# Acetanaerobacterium_elongatum_CGMCC_1_5012                     2
# Acetatifactor_muris_GP69                                       0
#
#                                             Beta-alanine metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                  0
# Acaricomes_phytoseiuli_DSM_14247                                  3
# Acaryochloris_marina_MBIC11017                                    1
# Acetanaerobacterium_elongatum_CGMCC_1_5012                        2
# Acetatifactor_muris_GP69                                          2
#
#                                             Bile acid metabolism  ...  \
# Row                                                               ...
# Abiotrophia_defectiva_ATCC_49176                               0  ...
# Acaricomes_phytoseiuli_DSM_14247                               0  ...
# Acaryochloris_marina_MBIC11017                                 0  ...
# Acetanaerobacterium_elongatum_CGMCC_1_5012                     0  ...
# Acetatifactor_muris_GP69                                       0  ...
#
#                                             Valerate metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                              0
# Acaricomes_phytoseiuli_DSM_14247                              0
# Acaryochloris_marina_MBIC11017                                0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                    0
# Acetatifactor_muris_GP69                                      0
#
#                                             Valine, leucine, and isoleucine metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                                    14
# Acaricomes_phytoseiuli_DSM_14247                                                    13
# Acaryochloris_marina_MBIC11017                                                      11
# Acetanaerobacterium_elongatum_CGMCC_1_5012                                           5
# Acetatifactor_muris_GP69                                                             8
#
#                                             Vitamin B12 metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                 4
# Acaricomes_phytoseiuli_DSM_14247                                 2
# Acaryochloris_marina_MBIC11017                                  15
# Acetanaerobacterium_elongatum_CGMCC_1_5012                       4
# Acetatifactor_muris_GP69                                         1
#
#                                             Vitamin B2 metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                1
# Acaricomes_phytoseiuli_DSM_14247                                1
# Acaryochloris_marina_MBIC11017                                  0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                      1
# Acetatifactor_muris_GP69                                        1
#
#                                             Vitamin B6 metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                7
# Acaricomes_phytoseiuli_DSM_14247                                4
# Acaryochloris_marina_MBIC11017                                  5
# Acetanaerobacterium_elongatum_CGMCC_1_5012                      8
# Acetatifactor_muris_GP69                                        9
#
#                                             Vitamin C metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                               0
# Acaricomes_phytoseiuli_DSM_14247                               0
# Acaryochloris_marina_MBIC11017                                 0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                     0
# Acetatifactor_muris_GP69                                       0
#
#                                             Wood-Ljungdahl Pathway  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                 0
# Acaricomes_phytoseiuli_DSM_14247                                 1
# Acaryochloris_marina_MBIC11017                                   2
# Acetanaerobacterium_elongatum_CGMCC_1_5012                       1
# Acetatifactor_muris_GP69                                         1
#
#                                             Xenobiotics metabolism  \
# Row
# Abiotrophia_defectiva_ATCC_49176                                 0
# Acaricomes_phytoseiuli_DSM_14247                                 2
# Acaryochloris_marina_MBIC11017                                   2
# Acetanaerobacterium_elongatum_CGMCC_1_5012                       1
# Acetatifactor_muris_GP69                                         0
#
#                                             Zeatin biosynthesis  tRNA Charging
# Row
# Abiotrophia_defectiva_ATCC_49176                              1              1
# Acaricomes_phytoseiuli_DSM_14247                              0              0
# Acaryochloris_marina_MBIC11017                                1              0
# Acetanaerobacterium_elongatum_CGMCC_1_5012                    0              1
# Acetatifactor_muris_GP69                                      0              1
#
# [5 rows x 114 columns]

# %%
fig,ax=plot_tsne_umap(data1,data2,df_agora_top_family,df_agora_top_class)
